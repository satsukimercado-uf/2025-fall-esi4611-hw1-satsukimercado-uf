# %% [markdown]
# ## Team 2 -Satsuki Mercado

# %%
# import file 
import mae
# run file 
mae.main()
# Out:
# part a:
#     x_mean    y_mean  x_var     y_var  xy_correlation
# 0     9.0  7.500909   10.0  3.752063        0.816421
# 1     9.0  7.500909   10.0  3.752390        0.816237
# 2     9.0  7.500000   10.0  3.747836        0.816287
# 3     9.0  7.500909   10.0  3.748408        0.816521
#
# part b:
# set  1 : y = 0.5 x +  3.0
# rmse = 1.1185
# set  2 : y = 0.5 x +  3.0
# rmse = 1.1191
# set  3 : y = 0.5 x +  3.0
# rmse = 1.1183
# set  4 : y = 0.5 x +  3.0
# rmse = 1.1177
#
# part c:
# The set for which the linear regression performs the best is set 4  with a RMSE of 1.1177 .
